# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b981f9e-107d-4591-bd9d-c3960f541c2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b981f9e-107d-4591-bd9d-c3960f541c2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cars93.csv to Cars93.csv

# %%
import pandas as pd
A = pd.read_csv("Cars93.csv")

# %% [markdown]
# **Importing the Modules**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# **Understanding the structure of the data**

# %%
A.head(5)
# Out:
#    Unnamed: 0 Manufacturer    Model  ... Weight   Origin           Make
# 0           1        Acura  Integra  ...   2705  non-USA  Acura Integra
# 1           2        Acura   Legend  ...   3560  non-USA   Acura Legend
# 2           3         Audi       90  ...   3375  non-USA        Audi 90
# 3           4         Audi      100  ...   3405  non-USA       Audi 100
# 4           5          BMW     535i  ...   3640  non-USA       BMW 535i
#
# [5 rows x 28 columns]

# %%
A.shape
# Out:
# (93, 28)

# %%
A.describe()
# Out:
#        Unnamed: 0  Min.Price  ...  Luggage.room       Weight
# count   93.000000  93.000000  ...     82.000000    93.000000
# mean    47.000000  17.125806  ...     13.890244  3072.903226
# std     26.990739   8.746029  ...      2.997967   589.896510
# min      1.000000   6.700000  ...      6.000000  1695.000000
# 25%     24.000000  10.800000  ...     12.000000  2620.000000
# 50%     47.000000  14.700000  ...     14.000000  3040.000000
# 75%     70.000000  20.300000  ...     15.000000  3525.000000
# max     93.000000  45.400000  ...     22.000000  4105.000000
#
# [8 rows x 19 columns]

# %%
A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          93 non-null     int64
#  1   Manufacturer        93 non-null     object
#  2   Model               93 non-null     object
#  3   Type                93 non-null     object
#  4   Min.Price           93 non-null     float64
#  5   Price               93 non-null     float64
#  6   Max.Price           93 non-null     float64
#  7   MPG.city            93 non-null     int64
#  8   MPG.highway         93 non-null     int64
#  9   AirBags             89 non-null     object
#  10  DriveTrain          93 non-null     object
#  11  Cylinders           93 non-null     object
#  12  EngineSize          93 non-null     float64
#  13  Horsepower          93 non-null     int64
#  14  RPM                 93 non-null     int64
# ...

# %% [markdown]
# **Missing Value Treatment**

# %%
A.isna().sum()
# Out:
# Unnamed: 0            0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
def replacer(df):
    Q = pd.DataFrame(df.isna().sum())
    Q.columns=["CT"]
    w = list(Q[Q.CT>0].index)
    
    cat = []
    con = []
    for i in w:
        if(df[i].dtypes=="object"):
            cat.append(i)
        else:
            con.append(i)

    for i in con:
        replacer = df[i].mean()
        df[i] = df[i].fillna(replacer)

    for i in cat:
        replacer = pd.DataFrame(df[i].value_counts()).index[0]
        df[i] = df[i].fillna(replacer)

# %%
replacer(A)

# %%
A.isna().sum()
# Out:
# Unnamed: 0            0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %% [markdown]
# ** Separating Categorical and Continueos Columns**

# %%
cat = []
con = []
for i in A.columns:
    if(A[i].dtypes=="object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Manufacturer',
#  'Model',
#  'Type',
#  'AirBags',
#  'DriveTrain',
#  'Cylinders',
#  'Man.trans.avail',
#  'Origin',
#  'Make']

# %%
con
# Out:
# ['Unnamed: 0',
#  'Min.Price',
#  'Price',
#  'Max.Price',
#  'MPG.city',
#  'MPG.highway',
#  'EngineSize',
#  'Horsepower',
#  'RPM',
#  'Rev.per.mile',
#  'Fuel.tank.capacity',
#  'Passengers',
#  'Length',
#  'Wheelbase',
#  'Width',
#  'Turn.circle',
#  'Rear.seat.room',
#  'Luggage.room',
#  'Weight']

# %% [markdown]
# Visualizing Categorical Data

# %%
plt.figure(figsize=(20,10))
plt1 = A.Manufacturer.value_counts().plot(kind = 'bar')
plt.title('Manufacturer')
plt1.set(xlabel = 'Manufacturer', ylabel='Frequency of Manufacturer')
# Out:
# [Text(0, 0.5, 'Frequency of Manufacturer'), Text(0.5, 0, 'Manufacturer')]

# %%
plt.figure(figsize=(10,10))
plt1 = A.Type.value_counts().plot(kind = 'bar')
plt.title('Type of the Car')
plt1.set(xlabel = 'Type', ylabel='Frequency of Type')
# Out:
# [Text(0, 0.5, 'Frequency of Type'), Text(0.5, 0, 'Type')]

# %%
Y = A[["AirBags"]]
X = A.drop(labels=["Unnamed: 0","AirBags","Manufacturer","Make","Model"],axis=1)

# %%
for i in X.columns:
    if(X[i].dtypes=="object"):
        sb.countplot(Y.AirBags,hue=X[i])
        plt.grid(linestyle = '--', axis='y')
        plt.show()
    else:
        sb.boxplot(Y.AirBags,X[i])
        plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...
